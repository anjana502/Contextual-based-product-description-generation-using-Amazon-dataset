# %%
pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/coder/Library/Python/3.12/lib/python/site-packages (4.46.2)
# Requirement already satisfied: filelock in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from transformers) (4.67.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coder/Library/Python/3.12/lib/python/site-packages (from requests->transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')

# %%
tokenizer.eos_token_id

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2-large', pad_token_id=tokenizer.eos_token_id)

# %%
tokenizer.eos_token_id
tokenizer.decode(tokenizer.eos_token_id)
# Out:
# '<|endoftext|>'

# %%
sentence = "I just put this on and it was creamy and a small amount can go a long way. I even put some on the outer eye wrinkles and the labial lines. I can feel the tightening as I type."
numeric_ids=tokenizer.encode(sentence, return_tensors="pt")

# %%
numeric_ids
# Out:
# tensor([[   40,   655,  1234,   428,   319,   290,   340,   373, 27892,   290,
#            257,  1402,  2033,   460,   467,   257,   890,   835,    13,   314,
#            772,  1234,   617,   319,   262, 12076,  4151, 49391,   290,   262,
#           2248,   498,  3951,    13,   314,   460,  1254,   262, 36040,   355,
#            314,  2099,    13]])

# %%
tokenizer.decode(numeric_ids[0][0])
# Out:
# 'I'

# %%
result = model.generate(numeric_ids, max_length=100, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
generated_text = tokenizer.decode(result[0], skip_special_tokens=True)
print(generated_text)
# Out:
# I just put this on and it was creamy and a small amount can go a long way. I even put some on the outer eye wrinkles and the labial lines. I can feel the tightening as I type.
#
# Rated 5 out of 5 by Anonymous from Love it! I've been using this product for a few months now and I love it. It's a little pricey, but it's worth every penny. The only thing I don't like about it is that it doesn't last
